# %%
# !pip install pgmpy
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/756.0 kB ? eta -:--:--
#    --------------------------------------- 756.0/756.0 kB 10.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#    - -------------------------------------- 3.1/110.9 MB 14.2 MB/s eta 0:00:08
#    - -------------------------------------- 5.5/110.9 MB 13.4 MB/s eta 0:00:08
#    -- ------------------------------------- 8.1/110.9 MB 12.6 MB/s eta 0:00:09
#    --- ------------------------------------ 10.7/110.9 MB 12.9 MB/s eta 0:00:08
#    ----- ---------------------------------- 14.2/110.9 MB 13.5 MB/s eta 0:00:08
#    ------ --------------------------------- 17.8/110.9 MB 14.2 MB/s eta 0:00:07
#    ------- -------------------------------- 21.2/110.9 MB 14.6 MB/s eta 0:00:07
# ...

# %%
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
